# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import datetime
import matplotlib.pyplot as plt

# %%
import pandas_datareader.data as web
start = datetime.datetime(2017, 1, 1)
end = datetime.datetime(2022, 1, 1)
SP500 = web.DataReader(['sp500'], 'fred', start, end)
# Out:
#               sp500
# DATE
# 2017-01-02      NaN
# 2017-01-03  2257.83
# 2017-01-04  2270.75
# 2017-01-05  2269.00
# 2017-01-06  2276.98
# ...             ...
# 2021-12-27  4791.19
# 2021-12-28  4786.35
# 2021-12-29  4793.06
# 2021-12-30  4778.73
# 2021-12-31  4766.18
#
# [1305 rows x 1 columns]

# %%
SP500['daily_return'] = (SP500['sp500']/ SP500['sp500'].shift(1)) -1
SP500.dropna(inplace = True)

# %%
SP500['daily_return'].plot(title='S&P 500 daily returns')
# Out:
# <AxesSubplot:title={'center':'S&P 500 daily returns'}, xlabel='DATE'>

# %%
SP500['sp500'].plot(title='S&P 500 Price')
# Out:
# <AxesSubplot:title={'center':'S&P 500 Price'}, xlabel='DATE'>

# %%
df_g = pd.read_csv("all_transactions.csv")

# %%
df_g
# Out:
#      transaction_date   owner ticker  \
# 0          04/04/2022  Spouse     --
# 1          03/09/2022    Self   TACO
# 2          03/29/2022    Self     --
# 3          03/21/2022    Self     --
# 4          03/21/2022    Self     --
# ...               ...     ...    ...
# 9331       08/17/2012     NaN    NaN
# 9332       08/16/2012     NaN    NaN
# 9333       08/15/2012     NaN    NaN
# 9334       08/02/2012     NaN    NaN
# 9335       07/25/2012     NaN    NaN
#
#                                       asset_description  \
# 0     Northern Lakes Capital IV, LP <div class="text...
# 1             Del Taco Restaurants, Inc. - Common Stock
# 2                                   Nov 22 CBT Soybeans
# 3                              Call Nov 22 CBT Soybeans
# 4                                   Nov 22 CBT Soybeans
# ...                                                 ...
# 9331  This filing was disclosed via scanned PDF. Use...
# 9332  This filing was disclosed via scanned PDF. Use...
# ...

# %%
stocks=df_g[['transaction_date','ticker','senator']]

# %%
stocks.ticker
# Out:
# 0         --
# 1       TACO
# 2         --
# 3         --
# 4         --
#         ...
# 9331     NaN
# 9332     NaN
# 9333     NaN
# 9334     NaN
# 9335     NaN
# Name: ticker, Length: 9336, dtype: object

# %%
from pandas.plotting import scatter_matrix

# !pip install yfinance

import yfinance as yf

# %matplotlib inline
# Out:
# ...
#      |████████████████████████████████| 63 kB 3.8 MB/s eta 0:00:011
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.10-py3-none-any.whl size=8488 sha256=9fa4073f4ec917c10dcdb78407853fec46186e2c2382a522a46b6fd123e5d56d
#   Stored in directory: /Users/sahajsingh/Library/Caches/pip/wheels/21/c9/66/b41c847de65c7985db52ec21d59996841598b8b0e93f2b9500
# Successfully built multitasking
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.9.1 requires ruamel-yaml, which is not installed.
# ...

# %%
start = "2017-01-01"
end = '2022-1-01'
aapl = yf.download('AAPL',start,end)
goog = yf.download('GOOGL',start,end)
FB = yf.download('FB',start,end)
MSFT = yf.download('MSFT',start,end)
AMZN = yf.download('AMZN',start,end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
aapl['returns'] = (aapl['Close']/tcs['Close'].shift(1)) -1
goog['returns'] = (goog['Close']/infy['Close'].shift(1))-1
FB['returns'] = (FB['Close']/wipro['Close'].shift(1)) - 1
MSFT['returns'] = (MSFT['Close']/wipro['Close'].shift(1)) - 1
AMZN['returns'] = (AMZN['Close']/wipro['Close'].shift(1)) - 1

aapl['returns'].hist(bins = 10, label = 'AAPL', alpha = 0.5,)
goog['returns'].hist(bins = 10, label = 'GOOG', alpha = 0.5)
MSFT['returns'].hist(bins = 10, label = 'MSFT', alpha = 0.5)
AMZN['returns'].hist(bins = 10, label = 'AMZN', alpha = 0.5)
plt.legend()

# %%
aapl['Open'].plot(label = 'AAPL', figsize = (15,7))
goog['Open'].plot(label = "GOOGL")
MSFT['Open'].plot(label = 'MSFT')
AMZN['Open'].plot(label = 'AMZN')
plt.title('Stock Prices of AAPL,GOOGL,MSFT,AMZN')
plt.legend()

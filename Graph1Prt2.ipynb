# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt


def getStockData(website):
    data = requests.get(website)
    #datadict = json.load(data.text)
    i = data.text
    data = json.loads(data.text)
    return data

def getDollars(dollstr):
    if dollstr.find("-") == -1:
        if dollstr.find("Over") > -1:
            sdoll = dollstr[5:].replace("$","").replace(",","")
            sdoll = float(sdoll)
            ldoll = sdoll
            return ldoll, sdoll
        print(dollstr)
        return 0,0
    sdoll, ldoll = dollstr.split("-")

    sdoll = sdoll.replace("$", "").replace(",", "")
    ldoll = ldoll.replace("$", "").replace(",", "")
    sdoll = float(sdoll)
    ldoll = float(ldoll)
    return sdoll, ldoll

def getAsset(asset):
    index = asset.find("<")
    if index == -1:
        asset = asset
    else:
        asset = asset[:index]
    return asset

def processData(data):
    companyDict = {}
    infoDict = {"total":0,"sdoll":0.00,"ldoll":0.00}
    for d in data:

        tdata = d["transactions"]
        for tran in tdata:
            try:
               tdate = tran["transaction_date"]
            except KeyError:
                continue
            asset = tran["asset_description"]
            asset = getAsset(asset)
            sdoll, ldoll = getDollars(tran["amount"])
            if asset not in companyDict.keys():
                infoDict = {"total": 0, "sdoll": 0.00, "ldoll": 0.00}
                companyDict[asset] = infoDict
            companyDict[asset]["total"] += 1
            companyDict[asset]["sdoll"] += sdoll
            companyDict[asset]["ldoll"] += ldoll
    return companyDict

def prepareChatdata(cdict,clist,cnt):
    comp = []
    sdoll = []
    ldoll = []
    count = 0;
    for key,value in cdict.items():

        srch = (value["ldoll"],value["sdoll"],value["total"],key)
        index = clist.index(srch)
        if index <cnt:
            comp.append(key)
            sdoll.append(value["sdoll"])
            ldoll.append(value["ldoll"])


    plt.xticks(rotation="vertical")

    plt.xlabel("Company",rotation=0)
    plt.ylabel("Min Dollar \ Max Doll")
    plt.title("Min Dollar \ Max Dollar by  Stock purchases for senators :")
    souts = plt.bar(comp, sdoll)
    walks = plt.bar(comp, ldoll, bottom=sdoll)
    plt.legend((souts[0], walks[0]), ("Min Dollars", "Max Dollars"), loc=0)
    plt.tight_layout()
    plt.show()

def topCharts(cdata):
    clist = []
    for key,value in cdata.items():
        clist.append((value["ldoll"],value["sdoll"],value["total"],key))
    clist.sort(reverse=True)
    return clist

#(data)
def printData(data):
    x=data[0]
    for key, value in data[0].items():
        print(f"{key}- {value}")
        if key == "transactions":
            for t in value:
              for key1, value1 in t.items():
                print(f"    {key1}- {value1}")
    x = 0
def main():
    website = "https://senate-stock-watcher-data.s3-us-west-2.amazonaws.com/aggregate/all_transactions_for_senators.json"
    stockData = getStockData(website)
    companyDict = processData(stockData)
    clist = topCharts(companyDict)
    prepareChatdata(companyDict,clist,20)
    i = 0

    printData(stockData)
main()
# Out:
# /var/folders/g6/y3nghk_j6fn9bprgztkqx3x00000gn/T/ipykernel_97427/4164674812.py:84: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# first_name- Tina
# last_name- Smith
# office- Smith, Tina (Senator)
# ptr_link- https://efdsearch.senate.gov/search/view/ptr/c1e81cf0-c49f-444e-b387-c12f3b0170fd/
# date_recieved- 04/20/2022
# transactions- [{'transaction_date': '04/04/2022', 'owner': 'Spouse', 'ticker': '--', 'asset_description': 'Northern Lakes Capital IV, LP <div class="text-muted"> <em>Company:</em> Northern Lakes Capital IV, LP &nbsp;(Minneapolis, MN) </div> <div class="text-muted"><em>Description:</em>&nbsp;Private Equity</div>', 'asset_type': 'Other Securities', 'type': 'Purchase', 'amount': '$15,001 - $50,000', 'comment': '--', 'ptr_link': 'https://efdsearch.senate.gov/search/view/ptr/c1e81cf0-c49f-444e-b387-c12f3b0170fd/'}, {'transaction_date': '04/11/2021', 'owner': 'Spouse', 'ticker': '--', 'asset_description': 'Surgical Information Sciences <div class="text-muted"> <em>Company:</em> Surgical Information Sciences &nbsp;(Alpharetta, CA) </div> <div class="text-muted"><em>Description:</em>&nbsp;Health Management Systems</div>', 'asset_type': 'Non-Public Stock', 'type': 'Purchase', 'amount': '$1,001 - $15,000', 'comment': '--', 'ptr_link': 'https://efdsearch.senate.gov/search/view/ptr/1c08a95d-02db-456c-8b96-e3e27ed2dc29/'}, {'transaction_date': '05/01/2020', 'owner': 'Spouse', 'ticker': '--', 'asset_description': 'Surgical Information Sciences <div class="text-muted"> <em>Company:</em> Surgical Information Sciences &nbsp;(Alpharetta, CA) </div> <div class="text-muted"><em>Description:</em>&nbsp;Health Management Systems</div>', 'asset_type': 'Other Securities', 'type': 'Purchase', 'amount': '$15,001 - $50,000', 'comment': '--', 'ptr_link': 'https://efdsearch.senate.gov/search/view/ptr/d6d82ed2-cdde-4953-9ac8-97566630a7a4/'}, {'transaction_date': '03/17/2020', 'owner': 'Spouse', 'ticker': '<a href="https://finance.yahoo.com/q?s=DXCM" target="_blank">DXCM</a>', 'asset_description': 'DexCom, Inc.', 'asset_type': 'Stock', 'type': 'Sale (Partial)', 'amount': '$250,001 - $500,000', 'comment': '--', 'ptr_link': 'https://efdsearch.senate.gov/search/view/ptr/8eae5ca1-bec4-44fd-b294-088d17ed7760/'}, {'transaction_date': '03/17/2020', 'owner': 'Spouse', 'ticker': '<a href="https://finance.yahoo.com/q?s=PODD" target="_blank">PODD</a>', 'asset_description': 'Insulet Corporation', 'asset_type': 'Stock', 'type': 'Sale (Partial)', 'amount': '$250,001 - $500,000', 'comment': '--', 'ptr_link': 'https://efdsearch.senate.gov/search/view/ptr/8eae5ca1-bec4-44fd-b294-088d17ed7760/'}, {'transaction_date': '10/16/2019', 'owner': 'Spouse', 'ticker': '--', 'asset_description': 'Surgical Information Sciences <div class="text-muted"> <em>Company:</em> Surgical Information Sciences &nbsp;(Alpharetta, CA) </div> <div class="text-muted"><em>Description:</em>&nbsp;Health Management Systems</div>', 'asset_type': 'Non-Public Stock', 'type': 'Purchase', 'amount': '$15,001 - $50,000', 'comment': '--', 'ptr_link': 'https://efdsearch.senate.gov/search/view/ptr/2c7444a7-64a1-412c-a6d7-c6b3c54de9fe/'}, {'transaction_date': '06/28/2018', 'owner': 'Spouse', 'ticker': '--', 'asset_description': 'Surgical Information Sciences <div class="text-muted"> <em>Company:</em> Surgical Information Sciences &nbsp;(Alpharetta, CA) </div> <div class="text-muted"><em>Description:</em>&nbsp;Health Management Systems</div>', 'asset_type': 'Non-Public Stock', 'type': 'Purchase', 'amount': '$15,001 - $50,000', 'comment': '--', 'ptr_link': 'https://efdsearch.senate.gov/search/view/ptr/e9e4b334-837b-46ad-86c1-f582d040faed/'}, {'transaction_date': '04/09/2019', 'owner': 'Joint', 'ticker': '<a href="https://finance.yahoo.com/q?s=ABT" target="_blank">ABT</a>', 'asset_description': 'Abbott Laboratories', 'asset_type': 'Stock', 'type': 'Sale (Full)', 'amount': '$250,001 - $500,000', 'comment': '--', 'ptr_link': 'https://efdsearch.senate.gov/search/view/ptr/a01704e8-58d6-42ee-a525-300381ea2f49/'}, {'transaction_date': '10/30/2018', 'owner': 'Spouse', 'ticker': '<a href="https://finance.yahoo.com/q?s=MSTY.PA" target="_blank">MSTY.PA</a>', 'asset_description': 'Mainstay Medical International plc', 'asset_type': 'Stock', 'type': 'Purchase', 'amount': '$50,001 - $100,000', 'comment': '--', 'ptr_link': 'https://ef ...
#     transaction_date- 04/04/2022
#     owner- Spouse
#     ticker- --
#     asset_description- Northern Lakes Capital IV, LP <div class="text-muted"> <em>Company:</em> Northern Lakes Capital IV, LP &nbsp;(Minneapolis, MN) </div> <div class="text-muted"><em>Description:</em>&nbsp;Private Equity</div>
#     asset_type- Other Securities
#     type- Purchase
#     amount- $15,001 - $50,000
#     comment- --
#     ptr_link- https://efdsearch.senate.gov/search/view/ptr/c1e81cf0-c49f-444e-b387-c12f3b0170fd/
#     transaction_date- 04/11/2021
#     owner- Spouse
#     ticker- --
#     asset_description- Surgical Information Sciences <div class="text-muted"> <em>Company:</em> Surgical Information Sciences &nbsp;(Alpharetta, CA) </div> <div class="text-muted"><em>Description:</em>&nbsp;Health Management Systems</div>
#     asset_type- Non-Public Stock
#     type- Purchase
#     amount- $1,001 - $15,000
#     comment- --
#     ptr_link- https://efdsearch.senate.gov/search/view/ptr/1c08a95d-02db-456c-8b96-e3e27ed2dc29/
#     transaction_date- 05/01/2020
#     owner- Spouse
#     ticker- --
#     asset_description- Surgical Information Sciences <div class="text-muted"> <em>Company:</em> Surgical Information Sciences &nbsp;(Alpharetta, CA) </div> <div class="text-muted"><em>Description:</em>&nbsp;Health Management Systems</div>
#     asset_type- Other Securities
#     type- Purchase
#     amount- $15,001 - $50,000
#     comment- --
#     ptr_link- https://efdsearch.senate.gov/search/view/ptr/d6d82ed2-cdde-4953-9ac8-97566630a7a4/
#     transaction_date- 03/17/2020
#     owner- Spouse
#     ticker- <a href="https://finance.yahoo.com/q?s=DXCM" target="_blank">DXCM</a>
#     asset_description- DexCom, Inc.
#     asset_type- Stock
#     type- Sale (Partial)
#     amount- $250,001 - $500,000
#     comment- --
#     ptr_link- https://efdsearch.senate.gov/search/view/ptr/8eae5ca1-bec4-44fd-b294-088d17ed7760/
#     transaction_date- 03/17/2020
#     owner- Spouse
#     ticker- <a href="https://finance.yahoo.com/q?s=PODD" target="_blank">PODD</a>
#     asset_description- Insulet Corporation
#     asset_type- Stock
#     type- Sale (Partial)
#     amount- $250,001 - $500,000
#     comment- --
#     ptr_link- https://efdsearch.senate.gov/search/view/ptr/8eae5ca1-bec4-44fd-b294-088d17ed7760/
#     transaction_date- 10/16/2019
#     owner- Spouse
#     ticker- --
#     asset_description- Surgical Information Sciences <div class="text-muted"> <em>Company:</em> Surgical Information Sciences &nbsp;(Alpharetta, CA) </div> <div class="text-muted"><em>Description:</em>&nbsp;Health Management Systems</div>
#     asset_type- Non-Public Stock
#     type- Purchase
#     amount- $15,001 - $50,000
#     comment- --
#     ptr_link- https://efdsearch.senate.gov/search/view/ptr/2c7444a7-64a1-412c-a6d7-c6b3c54de9fe/
#     transaction_date- 06/28/2018
#     owner- Spouse
#     ticker- --
#     asset_description- Surgical Information Sciences <div class="text-muted"> <em>Company:</em> Surgical Information Sciences &nbsp;(Alpharetta, CA) </div> <div class="text-muted"><em>Description:</em>&nbsp;Health Management Systems</div>
#     asset_type- Non-Public Stock
#     type- Purchase
#     amount- $15,001 - $50,000
#     comment- --
#     ptr_link- https://efdsearch.senate.gov/search/view/ptr/e9e4b334-837b-46ad-86c1-f582d040faed/
#     transaction_date- 04/09/2019
#     owner- Joint
#     ticker- <a href="https://finance.yahoo.com/q?s=ABT" target="_blank">ABT</a>
#     asset_description- Abbott Laboratories
#     asset_type- Stock
#     type- Sale (Full)
#     amount- $250,001 - $500,000
#     comment- --
#     ptr_link- https://efdsearch.senate.gov/search/view/ptr/a01704e8-58d6-42ee-a525-300381ea2f49/
#     transaction_date- 10/30/2018
#     owner- Spouse
#     ticker- <a href="https://finance.yahoo.com/q?s=MSTY.PA" target="_blank">MSTY.PA</a>
#     asset_description- Mainstay Medical International plc
#     asset_type- Stock
#     type- Purchase
#     amount- $50,001 - $100,000
#     comment- --
#     ptr_link- https://efdsearch.senate.gov/search/view/ptr/f02241a5-ba65-429f-ab64-3d97674f8e77/
#     transaction_date- 10/29/2018
#     owner- Spouse
#     ticker- <a href="https://finance.yahoo.com/q?s=MSTY.PA" target="_blank">MSTY.PA</a>
#     asset_description- Mainstay Medical International plc
#     asset_type- Stock
#     type- Purchase
#     amount- $50,001 - $100,000
#     comment- --
#     ptr_link- https://efdsearch.senate.gov/search/view/ptr/f02241a5-ba65-429f-ab64-3d97674f8e77/
#     transaction_date- 08/30/2018
#     owner- Spouse
#     ticker- <a href="https://finance.yahoo.com/q?s=PODD" target="_blank">PODD</a>
#     asset_description- Insulet Corporation
#     asset_type- Stock
#     type- Sale (Partial)
#     amount- $15,001 - $50,000
#     comment- --
#     ptr_link- https://efdsearch.senate.gov/search/view/ptr/2235b033-9cb7-43af-8e69-d55ce1a23561/
#     transaction_date- 08/30/2018
#     owner- Spouse
#     ticker- <a href="https://finance.yahoo.com/q?s=CUTR" target="_blank">CUTR</a>
#     asset_description- Cutera, Inc.
#     asset_type- Stock
#     type- Sale (Full)
#     amount- $100,001 - $250,000
#     comment- --
#     ptr_link- https://efdsearch.senate.gov/search/view/ptr/2235b033-9cb7-43af-8e69-d55ce1a23561/
#     transaction_date- 08/30/2018
#     owner- Spouse
#     ticker- <a href="https://finance.yahoo.com/q?s=CUTR" target="_blank">CUTR</a>
#     asset_description- Cutera, Inc.
#     asset_type- Stock
#     type- Sale (Full)
#     amount- $1,001 - $15,000
#     comment- --
#     ptr_link- https://efdsearch.senate.gov/search/view/ptr/2235b033-9cb7-43af-8e69-d55ce1a23561/
#     transaction_date- 08/30/2018
#     owner- Joint
#     ticker- <a href="https://finance.yahoo.com/q?s=PODD" target="_blank">PODD</a>
#     asset_description- Insulet Corporation
#     asset_type- Stock
#     type- Sale (Full)
#     amount- $250,001 - $500,000
#     comment- --
#     ptr_link- https://efdsearch.senate.gov/search/view/ptr/2235b033-9cb7-43af-8e69-d55ce1a23561/
#     transaction_date- 07/26/2018
#     owner- Spouse
#     ticker- <a href="https://finance.yahoo.com/q?s=IIN" target="_blank">IIN</a>
#     asset_description- IntriCon Corporation
#     asset_type- Stock
#     type- Sale (Partial)
#     amount- $100,001 - $250,000
#     comment- --
#     ptr_link- https://efdsearch.senate.gov/search/view/ptr/b5aa283c-4a0b-44f2-8571-e68bf04c6984/
#     transaction_date- 06/01/2018
#     owner- Spouse
#     ticker- <a href="https://finance.yahoo.com/q?s=TCMD" target="_blank">TCMD</a>
#     asset_description- Tactile Systems Technology, Inc.
#     asset_type- Stock
#     type- Sale (Partial)
#     amount- $100,001 - $250,000
#     comment- Asset held in Charles Schwab - Rollover IRA
#     ptr_link- https://efdsearch.senate.gov/search/view/ptr/fd4807b4-12c1-4014-9ed0-c4933dcb7446/
#     transaction_date- 06/01/2018
#     owner- Spouse
#     ticker- <a href="https://finance.yahoo.com/q?s=TCMD" target="_blank">TCMD</a>
#     asset_description- Tactile Systems Technology, Inc.
#     asset_type- Stock
#     type- Sale (Full)
#     amount- $100,001 - $250,000
#     comment- Asset held in Truchas Capital 401K Plan
#     ptr_link- https://efdsearch.senate.gov/search/view/ptr/fd4807b4-12c1-4014-9ed0-c4933dcb7446/
#     transaction_date- 06/01/2018
#     owner- Spouse
#     ticker- <a href="https://finance.yahoo.com/q?s=PODD" target="_blank">PODD</a>
#     asset_description- Insulet Corporation
#     asset_type- Stock
#     type- Sale (Partial)
#     amount- $100,001 - $250,000
#     comment- --
#     ptr_link- https://efdsearch.senate.gov/search/view/ptr/fd4807b4-12c1-4014-9ed0-c4933dcb7446/
#     transaction_date- 04/12/2018
#     owner- Spouse
#     ticker- <a href="https://finance.yahoo.com/q?s=CGNT" target="_blank">CGNT</a>
#     asset_description- Cogentix Medical, Inc.
#     asset_type- Stock
#     type- Sale (Partial)
#     amount- $15,001 - $50,000
#     comment- --
#     ptr_link- https://efdsearch.senate.gov/search/view/ptr/e4eae413-9ad7-4ccf-a37c-a277a55707cc/
#     transaction_date- 04/12/2018
#     owner- Spouse
#     ticker- <a href="https://finance.yahoo.com/q?s=CGNT" target="_blank">CGNT</a>
#     asset_description- Cogentix Medical, Inc.
#     asset_type- Stock
#     type- Sale (Full)
#     amount- $100,001 - $250,000
#     comment- --
#     ptr_link- https://efdsearch.senate.gov/search/view/ptr/e4eae413-9ad7-4ccf-a37c-a277a55707cc/
#     transaction_date- 04/10/2018
#     owner- Spouse
#     ticker- <a href="https://finance.yahoo.com/q?s=CGNT" target="_blank">CGNT</a>
#     asset_description- Cogentix Medical, Inc.
#     asset_type- Stock
#     type- Sale (Partial)
#     amount- $15,001 - $50,000
#     comment- --
#     ptr_link- https://efdsearch.senate.gov/search/view/ptr/e4eae413-9ad7-4ccf-a37c-a277a55707cc/
#     transaction_date- 03/29/2018
#     owner- Spouse
#     ticker- <a href="https://finance.yahoo.com/q?s=CGNT" target="_blank">CGNT</a>
#     asset_description- Cogentix Medical, Inc.
#     asset_type- Stock
#     type- Sale (Partial)
#     amount- $1,001 - $15,000
#     comment- --
#     ptr_link- https://efdsearch.senate.gov/search/view/ptr/5aa4f067-861b-466a-95e5-6d31e3d79ea1/
#     transaction_date- 03/02/2018
#     owner- Joint
#     ticker- <a href="https://finance.yahoo.com/q?s=PODD" target="_blank">PODD</a>
#     asset_description- Insulet Corporation
#     asset_type- Stock
#     type- Sale (Partial)
#     amount- $100,001 - $250,000
#     comment- --
#     ptr_link- https://efdsearch.senate.gov/search/view/ptr/63d39c23-dc3a-46ac-a187-086b780d8be7/
#     transaction_date- 01/16/2018
#     owner- Spouse
#     ticker- <a href="https://finance.yahoo.com/q?s=CUTR" target="_blank">CUTR</a>
#     asset_description- Cutera, Inc.
#     asset_type- Stock
#     type- Sale (Partial)
#     amount- $250,001 - $500,000
#     comment- --
#     ptr_link- https://efdsearch.senate.gov/search/view/ptr/981f36ec-4d37-4060-9091-8137d76e7a95/
#     transaction_date- 01/05/2018
#     owner- Joint
#     ticker- <a href="https://finance.yahoo.com/q?s=ENTL" target="_blank">ENTL</a>
#     asset_description- Entellus Medical, Inc.
#     asset_type- Stock
#     type- Sale (Full)
#     amount- $50,001 - $100,000
#     comment- --
#     ptr_link- https://efdsearch.senate.gov/search/view/ptr/981f36ec-4d37-4060-9091-8137d76e7a95/
# party- Democrat
# bioguide- S001203
# state- MN
